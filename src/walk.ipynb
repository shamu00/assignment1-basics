# %%
print(chr(29230))

print (len(chr(0)))

print ("this is a test" + chr(0) + "string")
# Out:
# 爮
# 1
# this is a teststring

# %%
"this is a test" + chr(0) + "string".__repr__()
# Out:
# "this is a test\x00'string'"

# %% [markdown]
# Q: How does this character’s string representation (__repr__()) differ from its printed representa-tion?
#
# A: repr() shows the **escaped** version of the string, suitable for debugging and unambiguous display; while print(s) prints the actual character, not an escaped form.

# %%
test_string="hello!こんにちは!"
utf8_encoded = test_string.encode('utf-16')

print(utf8_encoded)
# Out:
# b'hello!\xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'
